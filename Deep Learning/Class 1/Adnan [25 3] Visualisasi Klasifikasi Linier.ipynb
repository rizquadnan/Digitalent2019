# %% [markdown]
# <img src = "https://i.imgur.com/UjutVJd.jpg" align = "center">

# %% [markdown]
# # Visualisasi Bobot Klasifikasi Linier

# %% [markdown]
# ## *Deep Representations*
#
# Seperti yang telah dijelaskan sebelumnya, Salah satu intuisi alasan mengapa Jaringan yang dalam mampu mengatasi permasalahan lebih baik adalah dikarenakan Jaringan tersebut mampu membuat representasi permasalahan dengan lebih detil dan lebih baik
#
# Sebagai contoh, misalkan kita membangun Jaringan Saraf Tiruan untuk mengenali identitas seseorang berdasarkan citra wajah.
#
# <img src="https://image.ibb.co/iOG8MK/deep_representation.jpg" alt="deep_representation"/>
#
# Layer pertama pada Jaringan yang telah dilatih dengan ratusan dan ribuan citra mungkin akan bertindak lebih sebagai suatu pengenalan fitur atau *Edge Detection*, di mana setiap neuron mencoba mengenali orientasi garis yang berbeda. Kemudian terdapat layer berikutnya yang dilatih terhadap data garis hasil ekstraksi layer pertama dan menggabungkannya, dan mungkin membentuk suatu pengenalan fitur baru misalnya membentuk neuron yang mengenali fitur mata, hidung, dan lain sebagainya. Dan hal ini terus dilakukan untuk layer-layer berikutnya sehingga Jaringan dengan layer yang banyak dapat membentuk representasi fitur yang lebih detil.
#
# Namun apakah benar demikian?
# Mari kita selidiki

# %% [markdown]
# ## Klasifikasi Linier Multi-kelas
#
# Misal kita ingin melakukan klasifikasi citra 10 kelas menggunakan dataset CIFAR-10

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Download data cifar-10 dari TensorFlow

# %%
import tensorflow as tf


(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()


classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

print('X_train.shape =',X_train.shape)
print('y_train.shape =',y_train.shape)
print('X_test.shape  =',X_test.shape)
print('y_test.shape  =',y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# X_train.shape = (50000, 32, 32, 3)
# y_train.shape = (50000, 1)
# X_test.shape  = (10000, 32, 32, 3)
# y_test.shape  = (10000, 1)

# %% [markdown]
# Tampilkan 20 data pertama beserta kelasnya dari 50000 data latih

# %%
fig, ax = plt.subplots(2,10,figsize=(15,4.5))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
for j in range(0,2):
    for i in range(0, 10):
        ax[j,i].imshow(X_train[i+j*10])
        ax[j,i].set_title(classes[y_train[i+j*10,0]])
        ax[j,i].axis('off')
plt.show()

# %% [markdown]
# Selanjutnya kita akan mengklasifikasikan 10 kelas data cifar-10 menggunakan Klasifikasi Linier
#
# Untuk itu, pertama kali kita preprocessing data dengan melakukan *zero-mean centering*

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

mean_image = np.mean(X_train, axis = 0)
X_train -= mean_image # Centering ke 0
X_test -= mean_image # Centering ke 0

# %% [markdown]
# Pada Klasifikasi Linier, input harus diubah menjadi satu dimensi,
#
#
# <img src="https://i.ibb.co/HDTHkp9/linear-algebra.png" alt="klasifikasi linier"/>
#
#
# karena itu, lakukan reshape

# %%
X_train_reshape = X_train.reshape(50000, 32*32*3)
X_test_reshape = X_test.reshape(10000, 32*32*3)

y_train_reshape = y_train.ravel()
y_test_reshape = y_test.ravel()

print('X_train:', X_train_reshape.shape)
print('X_test:', X_test_reshape.shape)

print('y_train:', y_train_reshape.shape)
print('y_test:', y_test_reshape.shape)
# Out:
# X_train: (50000, 3072)
# X_test: (10000, 3072)
# y_train: (50000,)
# y_test: (10000,)

# %% [markdown]
# Selanjutnya kita lakukan pelatihan Klasifikasi Linier menggunakan library sklearn SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss='log', max_iter=2000, verbose=2, n_jobs=2,learning_rate='invscaling', eta0=1e-7)
clf.fit(X_train_reshape, y_train_reshape)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# -- Epoch 1
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.669306
# Total training time: 0.74 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.673584
# Total training time: 0.81 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.667376
# Total training time: 1.47 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.668709
# Total training time: 1.60 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.666922
# Total training time: 2.25 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.667320
# Total training time: 2.37 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.666616
# Total training time: 3.01 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.666399
# Total training time: 3.12 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.666494
# Total training time: 3.76 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.665733
# Total training time: 3.88 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.666340
# Total training time: 4.50 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.665265
# Total training time: 4.63 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.666230
# Total training time: 5.26 seconds.
# Convergence after 7 epochs took 5.26 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.664803
# Total training time: 5.39 seconds.
# -- Epoch 8
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.686147
# Total training time: 0.76 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000051, T: 400000, Avg. loss: 0.664475
# Total training time: 6.16 seconds.
# Convergence after 8 epochs took 6.16 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.683785
# Total training time: 1.53 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.684910
# Total training time: 0.77 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.683291
# Total training time: 2.28 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.682653
# Total training time: 1.52 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.682999
# Total training time: 3.04 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.682160
# Total training time: 2.28 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.682797
# Total training time: 3.80 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.681952
# Total training time: 3.04 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.682617
# Total training time: 4.56 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.681700
# Total training time: 3.81 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.682519
# Total training time: 5.31 seconds.
# Convergence after 7 epochs took 5.31 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.681645
# Total training time: 4.56 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.682297
# Total training time: 0.76 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.681530
# Total training time: 5.32 seconds.
# Convergence after 7 epochs took 5.32 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.679727
# Total training time: 1.52 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.681039
# Total training time: 0.78 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.679080
# Total training time: 2.30 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.678986
# Total training time: 1.54 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.678743
# Total training time: 3.06 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.678579
# Total training time: 2.30 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.678502
# Total training time: 3.82 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.678352
# Total training time: 3.07 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.678337
# Total training time: 4.58 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.678174
# Total training time: 3.83 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.678236
# Total training time: 5.34 seconds.
# Convergence after 7 epochs took 5.34 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.678034
# Total training time: 4.59 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.677967
# Total training time: 0.75 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.677948
# Total training time: 5.33 seconds.
# Convergence after 7 epochs took 5.33 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.674464
# Total training time: 1.51 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.681248
# Total training time: 0.77 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.673336
# Total training time: 2.27 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.677181
# Total training time: 1.52 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.672558
# Total training time: 3.02 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.675758
# Total training time: 2.28 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.672034
# Total training time: 3.77 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.675028
# Total training time: 3.03 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.671642
# Total training time: 4.52 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.674414
# Total training time: 3.78 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.671283
# Total training time: 5.28 seconds.
# -- Epoch 8
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.673938
# Total training time: 4.54 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000051, T: 400000, Avg. loss: 0.670994
# Total training time: 6.03 seconds.
# Convergence after 8 epochs took 6.03 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.673563
# Total training time: 5.29 seconds.
# -- Epoch 8
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.665646
# Total training time: 0.77 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000051, T: 400000, Avg. loss: 0.673214
# Total training time: 6.06 seconds.
# Convergence after 8 epochs took 6.06 seconds
# -- Epoch 1
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.663204
# Total training time: 1.52 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000018, T: 50000, Avg. loss: 0.668660
# Total training time: 0.75 seconds.
# -- Epoch 2
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.662616
# Total training time: 2.27 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000025, T: 100000, Avg. loss: 0.665715
# Total training time: 1.51 seconds.
# -- Epoch 3
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.662187
# Total training time: 3.02 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000031, T: 150000, Avg. loss: 0.664847
# Total training time: 2.27 seconds.
# -- Epoch 4
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.661943
# Total training time: 3.77 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000036, T: 200000, Avg. loss: 0.664296
# Total training time: 3.02 seconds.
# -- Epoch 5
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.661708
# Total training time: 4.52 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000040, T: 250000, Avg. loss: 0.663877
# Total training time: 3.77 seconds.
# -- Epoch 6
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.661482
# Total training time: 5.28 seconds.
# Convergence after 7 epochs took 5.28 seconds
# Norm: 0.00, NNZs: 3072, Bias: -0.000044, T: 300000, Avg. loss: 0.663651
# Total training time: 4.51 seconds.
# -- Epoch 7
# Norm: 0.00, NNZs: 3072, Bias: -0.000047, T: 350000, Avg. loss: 0.663376
# Total training time: 5.19 seconds.
# Convergence after 7 epochs took 5.19 seconds
# [Parallel(n_jobs=2)]: Done  10 out of  10 | elapsed:   28.1s finished
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=1e-07, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='invscaling', loss='log',
#               max_iter=2000, n_iter_no_change=5, n_jobs=2, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=2, warm_start=False)

# %% [markdown]
# Kita bisa mengecek akurasi dari model yang telah dilatih.
#
# Dapat dilihat bahwa akurasi masih kurang bagus dikarenakan kita hanya menggunakan klasifikasi linier atau Jaringan Saraf Tiruan satu layer

# %%
y_pred = clf.predict(X_test_reshape)

from sklearn.metrics import accuracy_score
print('akurasi =',accuracy_score(y_test_reshape, y_pred)*100,'%')
# Out:
# akurasi = 39.43 %

# %% [markdown]
# ## Visualisasi Bobot
#
# Selanjutnya mari kita ambil bobot yang telah dilatih dari model.
#
# Perhatikan bahwa ukuran bobot adalah (10 x 3072)

# %%
weights = clf.coef_
print(weights.shape)
# Out:
# (10, 3072)

# %% [markdown]
# Mari kita pilih salah satu kelas untuk kita tampilkan bobotnya

# %%
class_id = 0

w0 = weights[class_id]
print(w0.shape)
# Out:
# (3072,)

# %% [markdown]
# Normalisasi terlebih dahulu nilai bobot ke dalam rentang 0-1 agar dapat divisualisasikan

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((0.1,.9))
w0 = scaler.fit_transform(w0.reshape(-1, 1))

print(w0.shape)
# Out:
# (3072, 1)

# %% [markdown]
# Reshape kembali bobot ke ukuran (32x32) piksel

# %%
w0 = w0.reshape(32,32,3)
print(w0.shape)
# Out:
# (32, 32, 3)

# %% [markdown]
# Tampilkan bobotnya

# %%
plt.figure(figsize=(2,2))
plt.imshow(w0)
plt.title(classes[class_id])
plt.show()

# %% [markdown]
# Sekarang, mari kita tampilkan visualisasi keseluruhan bobot

# %%
fig, ax = plt.subplots(1,10,figsize=(18,5))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
for i in range(0, 10):
    w = weights[i]
    
    w = scaler.fit_transform(w.reshape(-1, 1))
    
    w = w.reshape((32,32,3))
    
    ax[i].imshow(w)
    ax[i].axis('off')
    ax[i].set_title(classes[i])
plt.show()

# %% [markdown]
# <p>Copyright &copy; 2019 ADF </p>
